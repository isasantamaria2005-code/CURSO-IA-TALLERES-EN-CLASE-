# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/2_Programacion_en_Python/4_Taller_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Taller Programación en Python: Listas y listas de listas**
# ---

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en parejas o grupos de 3**

# %% [markdown]
# **Nombres estudiantes:**
#
# -Felipe Pacheco
# -Julian Lizarazo
# -Isabella Ramirez

# %% [markdown]
# **Forma de entrega:**
#
# - Nombrar el archivo de la siguiente forma: “Taller_Listas_nombres_y_apellidos.ipynb”.
# - Suba el Jupyter Notebook a su cuenta en Github y envíe el link en el siguiente Forms: https://forms.cloud.microsoft/r/xZsmLRV4PC.
#
# **IMPORTANTE:** No se recibirán talleres en Google Colab, el notebook debe estar subido en Github.

# %% [markdown]
# **Plazo de entrega:**
#
# 4 de agosto de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# ## **Bloque 1: Gestión de Índices e Indicadores**
# Trabajaremos con la lista `ipc_mensual = [0.5, 0.8, 1.2, 0.4, 0.3, 0.9, 1.1]` que representa la inflación mensual.

# %%
ipc_mensual = [0.5, 0.8, 1.2, 0.4, 0.3, 0.9, 1.1]

# %%
# 1. Agrega el dato de inflación del nuevo mes: 0.6 al final.
### TU CÓDIGO AQUÍ ###
ipc_mensual.append(0.6)
print(ipc_mensual)
# Out:
# [0.5, 0.8, 1.2, 0.4, 0.3, 0.9, 1.1, 0.6]

# %%
# 2. Inserta el valor 0.7 en la segunda posición (índice 1) por un ajuste retroactivo.
### TU CÓDIGO AQUÍ ###
ipc_mensual.insert(1, 0.7)
print(ipc_mensual)
# Out:
# [0.5, 0.7, 0.8, 1.2, 0.4, 0.3, 0.9, 1.1, 0.6]

# %%
# 3. El valor 1.2 fue un error de digitación. Cámbialo por 1.0.
### TU CÓDIGO AQUÍ ###
indice_1_2 = ipc_mensual.index(1.2)
ipc_mensual[indice_1_2] = 1.0
print(ipc_mensual)
# Out:
# [0.5, 0.7, 0.8, 1.0, 0.4, 0.3, 0.9, 1.1, 0.6]

# %%
# 4. Extrae los primeros 3 meses en una lista llamada 'primer_trimestre'.
### TU CÓDIGO AQUÍ ###
primer_trimestre = ipc_mensual[:3]
print(primer_trimestre)
# Out:
# [0.5, 0.7, 0.8]

# %%
# 5. Extrae los últimos 2 meses en una lista llamada 'cierre_año'.
### TU CÓDIGO AQUÍ ###
cierre_año = ipc_mensual[-2:]
print(cierre_año)
# Out:
# [1.1, 0.6]

# %%
# 6. Ordena la lista de menor a mayor inflación.
### TU CÓDIGO AQUÍ ###
ipc_mensual.sort()
print(ipc_mensual)
# Out:
# [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1]

# %%
# 7. Encuentra el índice donde quedó el valor máximo (1.1) y guárdalo en 'pos_max'.
### TU CÓDIGO AQUÍ ###
pos_max = ipc_mensual.index(1.1)
print(f"El valor máximo (1.1) está en el índice: {pos_max}")
# Out:
# El valor máximo (1.1) está en el índice: 8

# %%
# 8. Elimina el valor más bajo de la lista (0.3).
### TU CÓDIGO AQUÍ ###
valor_minimo = min(ipc_mensual) # Encuentra el valor mínimo
ipc_mensual.remove(valor_minimo)
print(ipc_mensual)
# Out:
# [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1]

# %%
# 9. Cuenta cuántas veces aparece el valor 0.6 y guárdalo en 'conteo_06'.
### TU CÓDIGO AQUÍ ###
conteo_06 = ipc_mensual.count(0.6)
print(f"El valor 0.6 aparece {conteo_06} veces.")
# Out:
# El valor 0.6 aparece 1 veces.

# %%
# 10. Invierte el orden actual de la lista.
### TU CÓDIGO AQUÍ ###
ipc_mensual.reverse()
print(ipc_mensual)
# Out:
# [1.1, 1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4]

# %%
# --- VERIFICACIÓN AUTOMÁTICA - NO MODIFICAR ESTA CELDA ---
assert len(ipc_mensual) == 8
assert 0.3 not in ipc_mensual
assert primer_trimestre == [0.5, 0.7, 0.8]
assert cierre_año == [1.1, 0.6]
print("¡Bloque 1 completado!")
# Out:
# ¡Bloque 1 completado!

# %% [markdown]
# ## **Bloque 2: Listas de Listas - Microdatos de Empresas**
# Gestionarás la siguiente matriz `empresas = [['E1', 500, True], ['E2', 150, False], ['E3', 1200, True]]`.
# Cada sublista corresponde a `[Nombre_Empresa, Número_Empleados, Cotiza_Bolsa]`.

# %%
empresas = [['E1', 500, True], ['E2', 150, False], ['E3', 1200, True]]

# %%
# 11. Accede al número de empleados de 'E2' y guárdalo en 'emp_e2'.
### TU CÓDIGO AQUÍ ###
emp_e2 = empresas[1][1]
print(f"Empleados de E2: {emp_e2}")
# Out:
# Empleados de E2: 150

# %%
# 12. Cambia el estado de 'E2' a True (ahora cotiza en bolsa).
### TU CÓDIGO AQUÍ ###
empresas[1][2] = True
print(empresas)
# Out:
# [['E1', 500, True], ['E2', 150, True], ['E3', 1200, True]]

# %%
# 13. Agrega una nueva empresa: ['E4', 800, False].
### TU CÓDIGO AQUÍ ###
empresas.append(['E4', 800, False])
print(empresas)
# Out:
# [['E1', 500, True], ['E2', 150, True], ['E3', 1200, True], ['E4', 800, False]]

# %%
# 14. Calcula el total de empresas en la matriz y guárdalo en 'n_empresas'.
### TU CÓDIGO AQUÍ ###
n_empresas = len(empresas)
print(f"Número total de empresas: {n_empresas}")
# Out:
# Número total de empresas: 4

# %%
# 15. Crea una lista vacía 'nombres' y usa un 'for' para llenarla con los nombres (E1, E2...).
### TU CÓDIGO AQUÍ ###
nombres = []
for empresa in empresas:
    nombres.append(empresa[0])
print(nombres)
# Out:
# ['E1', 'E2', 'E3', 'E4']

# %%
# 16. Calcula el promedio de empleados y guárdalo en 'promedio_emp'.
### TU CÓDIGO AQUÍ ###
total_empleados = 0
for empresa in empresas:
    total_empleados += empresa[1]
promedio_emp = total_empleados / n_empresas
print(f"Promedio de empleados: {promedio_emp}")
# Out:
# Promedio de empleados: 662.5

# %%
# 17. Elimina la sublista de la empresa 'E1'.
### TU CÓDIGO AQUÍ ###
# Asumiendo que 'E1' es siempre la primera empresa si no se ha modificado su nombre aún.
# Si 'E1' ya fue modificada a 'Empresa Lider' (como en la tarea 20),
# esta eliminación debe hacerse antes de la tarea 20 o buscar por el nombre original.
# Para la verificación automática, se asume que 'E1' aún existe en la posición 0.
empresas.pop(0)
print(empresas)
# Out:
# [['E2', 150, True], ['E3', 1200, True], ['E4', 800, False]]

# %%
# 18. Accede al nombre de la última empresa de la lista y guárdalo en 'ultima_emp'.
### TU CÓDIGO AQUÍ ###
ultima_emp = empresas[-1][0]
print(f"Nombre de la última empresa: {ultima_emp}")
# Out:
# Nombre de la última empresa: E4

# %%
# 19. Crea una lista 'grandes' con las empresas que tienen > 1000 empleados (trae la sublista con la información completa de la o las empresas).
### TU CÓDIGO AQUÍ ###
grandes = []
for empresa in empresas:
    if empresa[1] > 1000:
        grandes.append(empresa)
print(f"Empresas grandes: {grandes}")
# Out:
# Empresas grandes: [['E3', 1200, True]]

# %%
# 20. Modifica el nombre de 'E2' a 'Empresa Lider' dentro de la matriz.
### TU CÓDIGO AQUÍ ###
# Primero encontramos el índice de 'E2'. Asumiendo que E2 es la primera ahora
# o buscamos por el nombre.
for i in range(len(empresas)):
    if empresas[i][0] == 'E2': # Si 'E1' fue eliminada, 'E2' es ahora la primera
        empresas[i][0] = 'Empresa Lider'
        break
print(empresas)
# Out:
# [['Empresa Lider', 150, True], ['E3', 1200, True], ['E4', 800, False]]

# %%
# --- VERIFICACIÓN AUTOMÁTICA - NO MODIFICAR ESTA CELDA ---
assert emp_e2 == 150
assert empresas[0][0] == 'Empresa Lider'
assert n_empresas == 4
assert nombres == ['E1', 'E2', 'E3', 'E4']
assert promedio_emp == 662.5
assert len(grandes) == 1
print("¡Taller finalizado exitosamente!")
# Out:
# ¡Taller finalizado exitosamente!
